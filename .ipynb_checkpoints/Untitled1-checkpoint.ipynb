# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import time
import os

# Import your modules
import utils
import sofm

# %%
def run_synthetic_study():
    sample_sizes = [200, 1000, 5000, 10000]
    n_replications = 20
    results = []

    print(f"Starting Synthetic Study: {len(sample_sizes)} sample sizes, {n_replications} reps each.")
    
    for n_samples in sample_sizes:
        print(f"\n{'='*40}")
        print(f"Running Sample Size: N = {n_samples}")
        print(f"{'='*40}")
        
        for rep in range(n_replications):
            start_time = time.time()
            
            # 1. Generate Data
            da, lam_lat, lam_lon, rot, U_true, L_true, sigma_true = utils._gen_spat_da(
                sq_len=10, 
                k=3, 
                n_samples=n_samples, 
                max_lag=20, 
                ls1=1, 
                ls2=1, 
                mode='gradient',
                sigma = 5
            )
            
            # 2. Initialize and Fit Model
            # Note: Ensure block_sz matches your init parameter name (block_sz vs block_sz)
            mod = sofm.SOFM(da, n_components=3, nonstationary=True, block_sz=1, n_blocks=40)
            mod.fit(phis=[1e2,1e3,1e4])
            sc = mod.spatcov_
            lat_mse = np.mean((sc.lam_lat_ - lam_lat)**2)
            lon_mse = np.mean((sc.lam_lon_ - lam_lon)**2)
            rot_mse = np.mean((sc.rot_ - rot)**2)

            # 3. Calculate Loss for U (Accounting for Sign Ambiguity)
            U_est = mod.U_.detach().numpy() if torch.is_tensor(mod.U_) else mod.U_
            U_true_np = U_true.detach().numpy() if torch.is_tensor(U_true) else U_true
            
            U_loss = 0.0
            for k in range(U_est.shape[1]):
                # Check MSE for both standard and flipped signs
                mse_plus = np.mean((U_est[:, k] - U_true_np[:, k])**2)
                mse_minus = np.mean((U_est[:, k] + U_true_np[:, k])**2)
                U_loss += min(mse_plus, mse_minus)
            U_loss /= U_est.shape[1] # Average MSE across the k components
            
            # 4. Calculate Loss for L
            L_est = mod.L_.detach().numpy() if torch.is_tensor(mod.L_) else mod.L_
            L_true_np = L_true.detach().numpy() if torch.is_tensor(L_true) else L_true
            L_loss = np.mean((L_est - L_true_np)**2)
            
            # 5. Calculate Loss for Sigma
            # Assuming mod.sigma2_ is variance, we take sqrt to compare to sigma_true
            sigma_est = np.sqrt(mod.sigma2_) if not torch.is_tensor(mod.sigma2_) else torch.sqrt(mod.sigma2_).item()
            sigma_true_val = sigma_true.item() if torch.is_tensor(sigma_true) else sigma_true
            sigma_loss = (sigma_est - sigma_true_val)**2
            
            run_time = time.time() - start_time
            print(f"  Rep {rep+1}/{n_replications} | Time: {run_time:.1f}s | U_MSE: {U_loss:.5f} | L_MSE: {L_loss:.2f}")
            
            # Store results
            results.append({
                'Sample_Size': n_samples,
                'Replication': rep + 1,
                'U_MSE': U_loss,
                'L_MSE': L_loss,
                'Sigma_MSE': float(sigma_loss),
                'lat_MSE': lat_mse,
                'lon_MSE': lon_mse,
                'rot_MSE': rot_mse
            })

    # Save to CSV
    df_results = pd.DataFrame(results)
    csv_filename = "sofm_synthetic_results.csv"
    df_results.to_csv(csv_filename, index=False)
    print(f"\nStudy complete! Results saved to {csv_filename}")
    
    return df_results

# %%
def plot_consistency(df_results):
    """Generates boxplots to visualize consistency (variance shrinking as N increases)."""
    
    sns.set_theme(style="whitegrid")
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    
    # Plot U Loss
    sns.boxplot(data=df_results, x='Sample_Size', y='U_MSE', ax=axes[0][0], color='blue', showfliers=False)
    sns.stripplot(data=df_results, x='Sample_Size', y='U_MSE', ax=axes[0][0], color='black', alpha=0.5, size=4)
    axes[0][0].set_title('Loadings (U)')
    axes[0][0].set_ylabel('Mean squared error')
    axes[0][0].set_xlabel('Sample size')

    # Plot L Loss
    sns.boxplot(data=df_results, x='Sample_Size', y='L_MSE', ax=axes[0][1], color='blue', showfliers=False)
    sns.stripplot(data=df_results, x='Sample_Size', y='L_MSE', ax=axes[0][1], color='black', alpha=0.5, size=4)
    axes[0][1].set_title('Singular values (L)')
    axes[0][1].set_ylabel('Mean squared error')
    axes[0][1].set_xlabel('Sample size')

    # Plot Sigma Loss
    sns.boxplot(data=df_results, x='Sample_Size', y='Sigma_MSE', ax=axes[0][2], color='blue', showfliers=False)
    sns.stripplot(data=df_results, x='Sample_Size', y='Sigma_MSE', ax=axes[0][2], color='black', alpha=0.5, size=4)
    axes[0][2].set_title('Repeated singular value (sigma)')
    axes[0][2].set_ylabel('Squared error')
    axes[0][2].set_xlabel('Sample size')

    # Plot lat Loss
    sns.boxplot(data=df_results, x='Sample_Size', y='lat_MSE', ax=axes[1][0], color='blue', showfliers=False)
    sns.stripplot(data=df_results, x='Sample_Size', y='lat_MSE', ax=axes[1][0], color='black', alpha=0.5, size=4)
    axes[1][0].set_title('Latitudinal length scales')
    axes[1][0].set_ylabel('Mean squared error')
    axes[1][0].set_xlabel('Sample size')

    # Plot lon Loss
    sns.boxplot(data=df_results, x='Sample_Size', y='lon_MSE', ax=axes[1][1], color='blue', showfliers=False)
    sns.stripplot(data=df_results, x='Sample_Size', y='lon_MSE', ax=axes[1][1], color='black', alpha=0.5, size=4)
    axes[1][1].set_title('Longitudinal length scales')
    axes[1][1].set_ylabel('Mean squared error')
    axes[1][1].set_xlabel('Sample size')

    # Plot rot Loss
    sns.boxplot(data=df_results, x='Sample_Size', y='rot_MSE', ax=axes[1][2], color='blue', showfliers=False)
    sns.stripplot(data=df_results, x='Sample_Size', y='rot_MSE', ax=axes[1][2], color='black', alpha=0.5, size=4)
    axes[1][2].set_title('Rotations')
    axes[1][2].set_ylabel('Squared error')
    axes[1][2].set_xlabel('Sample size')

    plt.tight_layout()
    plt.savefig("sofm_consistency_plots.png", dpi=300)
    plt.show()

# %%
df = run_synthetic_study()
# Out:
# Starting Synthetic Study: 4 sample sizes, 20 reps each.
#
# ...
# Running Sample Size: N = 200
# ...
# [16:26:38] Estimating prior spatial covariance...
# Validating length scales: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:03<00:00,  8.21it/s]
# Fitting spline to the optimal length scales...
# Latitudinal spline | Knots: 10 | gamma_u: 1.00e+01 | gamma_v: 1.00e+03
# Longitudinal spline | Knots: 10 | gamma_u: 3.73e-01 | gamma_v: 1.00e+03
# Rotational spline | Knots: 10 | gamma_u: 3.73e+01 | gamma_v: 1.00e+03
# Validating sill: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 60.41it/s]
# Refitting full model...
# ...

# %%
plot_consistency(df)

# %%
sq_len = 50
da, lam_lat, lam_lon, rot, U_true, L_true, sigma_true = utils._gen_spat_da(
    sq_len=sq_len, 
    k=3, 
    n_samples=30000,
    max_lag=20, 
    ls1=1, 
    ls2=1, 
    mode='circle',
    sigma = 10
)

# 2. Initialize and Fit Model
# Note: Ensure block_sz matches your init parameter name (block_sz vs block_sz)
mod = sofm.SOFM(da, n_components=3, nonstationary=True, block_sz=1, n_blocks=int(sq_len**2/3))
mod.fit(phis=[1e2,1e3,1e4])
sc = mod.spatcov_
lat_mse = np.mean((sc.lam_lat_ - lam_lat)**2)
lon_mse = np.mean((sc.lam_lon_ - lam_lon)**2)
rot_mse = np.mean((sc.rot_ - rot)**2)
# Out:
# [20:35:04] Estimating prior spatial covariance...
# Validating length scales:   0%|                                                                                                                                                                | 0/27 [00:00<?, ?it/s]

# %%
da = da.set_index(location=['lat', 'lon'])

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# ==========================================
# 1. Prepare Ground Truth DataArrays
# ==========================================
W_da_gt = xr.DataArray(
    data=lam_lat,
    dims=('location'),
    coords={'location': da.location}
).unstack().sortby('lon','lat')

W_da2_gt = xr.DataArray(
    data=lam_lon,
    dims=('location'),
    coords={'location': da.location}
).unstack().sortby('lon','lat')

W_da3_gt = xr.DataArray(
    data=rot,
    dims=('location'),
    coords={'location': da.location}
).unstack().sortby('lon','lat')

# ==========================================
# 2. Prepare Estimated DataArrays (from 'sc')
# ==========================================
W_da_est = xr.DataArray(
    data=sc.lam_lat_,
    dims=('location'),
    coords={'location': da.location} 
).unstack().sortby('lon','lat')

W_da2_est = xr.DataArray(
    data=sc.lam_lon_,
    dims=('location'),
    coords={'location': da.location}
).unstack().sortby('lon','lat')

W_da3_est = xr.DataArray(
    data=sc.rot_,
    dims=('location'),
    coords={'location': da.location}
).unstack().sortby('lon','lat')

# ==========================================
# 3. Create the 2x3 Plot
# ==========================================
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# --- ROW 0: Ground Truth ---
W_da_gt.plot(ax=axes[0, 0], cmap=cm.plasma, add_colorbar=True, robust=True, cbar_kwargs={'format': '%.1f'})
axes[0, 0].set_title('True Latitudinal length scale')
axes[0, 0].set_xlabel('Longitude')
axes[0, 0].set_ylabel('Latitude')

W_da2_gt.plot(ax=axes[0, 1], cmap=cm.plasma, add_colorbar=True, robust=True, cbar_kwargs={'format': '%.1f'})
axes[0, 1].set_title('True Longitudinal length scale')
axes[0, 1].set_xlabel('Longitude')
axes[0, 1].set_ylabel('Latitude')

# W_da3_gt.plot(ax=axes[0, 2], cmap=cm.plasma, add_colorbar=True, robust=True, cbar_kwargs={'format': '%.1f'})
# axes[0, 2].set_title('True Rotation')
# axes[0, 2].set_xlabel('Longitude')
# axes[0, 2].set_ylabel('Latitude')

# --- ROW 1: Estimates ---
W_da_est.plot(ax=axes[1, 0], cmap=cm.plasma, add_colorbar=True, robust=True, cbar_kwargs={'format': '%.1f'})
axes[1, 0].set_title('Est. Latitudinal length scale')
axes[1, 0].set_xlabel('Longitude')
axes[1, 0].set_ylabel('Latitude')

W_da2_est.plot(ax=axes[1, 1], cmap=cm.plasma, add_colorbar=True, robust=True, cbar_kwargs={'format': '%.1f'})
axes[1, 1].set_title('Est. Longitudinal length scale')
axes[1, 1].set_xlabel('Longitude')
axes[1, 1].set_ylabel('Latitude')

# W_da3_est.plot(ax=axes[1, 2], cmap=cm.plasma, add_colorbar=True, robust=True, cbar_kwargs={'format': '%.1f'})
# axes[1, 2].set_title('Est. Rotation')
# axes[1, 2].set_xlabel('Longitude')
# axes[1, 2].set_ylabel('Latitude')

plt.tight_layout()
plt.savefig("sofm_circular_example_v1.png", dpi=300)
plt.show()
